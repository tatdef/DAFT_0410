# %% [markdown]
# # Web Scraping Lab
#
# You will find in this notebook some scrapy exercises to practise your scraping skills.
#
# **Tips:**
#
# - Check the response status code for each request to ensure you have obtained the intended content.
# - Print the response text in each request to understand the kind of info you are getting and its format.
# - Check for patterns in the response text to extract the data/info requested in each question.
# - Visit the urls below and take a look at their source code through Chrome DevTools. You'll need to identify the html tags, special class names, etc used in the html content you are expected to extract.
#
# **Resources**:
# - [Requests library](http://docs.python-requests.org/en/master/#the-user-guide)
# - [Beautiful Soup Doc](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Urllib](https://docs.python.org/3/library/urllib.html#module-urllib)
# - [re lib](https://docs.python.org/3/library/re.html)
# - [lxml lib](https://lxml.de/)
# - [Scrapy](https://scrapy.org/)
# - [List of HTTP status codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)
# - [HTML basics](http://www.simplehtmlguide.com/cheatsheet.php)
# - [CSS basics](https://www.cssbasics.com/#page_start)

# %% [markdown]
# #### Below are the libraries and modules you may need. `requests`,  `BeautifulSoup` and `pandas` are already imported for you. If you prefer to use additional libraries feel free to do it.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# #### Download, parse (using BeautifulSoup), and print the content from the Trending Developers page from GitHub:

# %%
# This is the url you will scrape in this exercise
url1 = 'https://github.com/trending/developers'
html1=requests.get(url1)
html1
# Out:
# <Response [200]>

# %%
html1=html1.content
print(html1[0:100])
# Out:
# b'\n\n<!DOCTYPE html>\n<html lang="en" data-color-mode="auto" data-light-theme="light" data-dark-theme="d'

# %%
soup1 = BeautifulSoup(html1, 'html.parser')

# %%
soup1.prettify()
# Out:
# '<!DOCTYPE html>\n<html data-a11y-animated-images="system" data-color-mode="auto" data-dark-theme="dark" data-light-theme="light" lang="en">\n <head>\n  <meta charset="utf-8"/>\n  <link href="https://github.githubassets.com" rel="dns-prefetch"/>\n  <link href="https://avatars.githubusercontent.com" rel="dns-prefetch"/>\n  <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>\n  <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>\n  <link crossorigin="" href="https://github.githubassets.com" rel="preconnect"/>\n  <link href="https://avatars.githubusercontent.com" rel="preconnect"/>\n  <link crossorigin="anonymous" href="https://github.githubassets.com/assets/light-0946cdc16f15.css" media="all" rel="stylesheet">\n   <link crossorigin="anonymous" href="https://github.githubassets.com/assets/dark-3946c959759a.css" media="all" rel="stylesheet">\n    <link crossorigin="anonymous" data-color-theme="dark_dimmed" data-href="https://github.githubasset
# ...

# %% [markdown]
# #### Display the names of the trending developers retrieved in the previous step.
#
# Your output should be a Python list of developer names. Each name should not contain any html tag.
#
# **Instructions:**
#
# 1. Find out the html tag and class names used for the developer names. You can achieve this using Chrome DevTools.
#
# 1. Use BeautifulSoup to extract all the html elements that contain the developer names.
#
# 1. Use string manipulation techniques to replace whitespaces and linebreaks (i.e. `\n`) in the *text* of each html element. Use a list to store the clean names.
#
# 1. Print the list of names.
#
# Your output should look like below:
#
# ```
# ['trimstray (@trimstray)',
#  'joewalnes (JoeWalnes)',
#  'charlax (Charles-AxelDein)',
#  'ForrestKnight (ForrestKnight)',
#  'revery-ui (revery-ui)',
#  'alibaba (Alibaba)',
#  'Microsoft (Microsoft)',
#  'github (GitHub)',
#  'facebook (Facebook)',
#  'boazsegev (Bo)',
#  'google (Google)',
#  'cloudfetch',
#  'sindresorhus (SindreSorhus)',
#  'tensorflow',
#  'apache (TheApacheSoftwareFoundation)',
#  'DevonCrawford (DevonCrawford)',
#  'ARMmbed (ArmMbed)',
#  'vuejs (vuejs)',
#  'fastai (fast.ai)',
#  'QiShaoXuan (Qi)',
#  'joelparkerhenderson (JoelParkerHenderson)',
#  'torvalds (LinusTorvalds)',
#  'CyC2018',
#  'komeiji-satori (神楽坂覚々)',
#  'script-8']
#  ```

# %%
container = soup1.select("div.col-md-6")
container=list(container)
container=container[0:-1:2]
container[1].select_one('h1').text
container[1].select_one('p').text
# Out:
# '\n\n              merrymercy\n '

# %%
trending_devs=[]
for i in container:
    name = i.select_one('h1').text
    if i.select_one('p') is not None:
        handle = i.select_one('p').text
    else:
        handle = ' '
    trending_devs.append(f"{name.strip()}({handle.strip()})")
trending_devs
# Out:
# ['Harrison Chase(hwchase17)',
#  'Lianmin Zheng(merrymercy)',
#  'Henrik Rydgård(hrydgard)',
#  'Peer Richelsen(PeerRich)',
#  'Evgenii Bazhanov(Ebazhanov)',
#  'Rui Chen(chenrui333)',
#  'oobabooga()',
#  'Michael Bui(MaikuB)',
#  'Fons van der Plas(fonsp)',
#  'Jerry Liu(jerryjliu)',
#  'Matthew Leibowitz(mattleibow)',
#  'Bjorn Lu(bluwy)',
#  'Sam Clegg(sbc100)',
#  'Ammar Ahmed(ammarahm-ed)',
#  'Richard Hughes(hughsie)',
#  'Dan Gohman(sunfishcode)',
#  'Mattias Wadman(wader)',
#  'lllyasviel()',
#  'Paweł Bylica(chfast)',
#  'Kirat(hkirat)',
#  'Laurent Mazare(LaurentMazare)',
#  'Leonid Bugaev(buger)',
#  'Resi Respati(resir014)',
#  'Payton Swick(sirbrillig)',
#  'Ashley Mannix(KodrAus)']

# %% [markdown]
# ### Archive of a horrible few hours spent on this exercise
# ```
# div = soup1.findAll('h1', {"class":"h3 lh-condensed"})
# for a in div:
#     a=a.get_text()
#     names.append(a.strip())
#
# print(names)
# print(len(names))
#
# handle=[]
# pattern='[^.*]'
# div2=soup1.findAll('p', {"class":"f4 text-normal mb-1"})
# for b in div2:
#     b=b.get_text()
#     if re.search('[\w{2}]', b):
#         handle.append(b.strip())
#     else:
#         handle.append("NA")
#
# print(handle)
# print(len(handle))
#
# df=pd.DataFrame({
#     'names': names
#     })
# print(df)
# ```
# the problem is that one of the names doesn't have a handle am trying to create a list where empty would return NA, but not sure the findall in the page is actually finding an empty reference.
#
# ```
# names4=[]
# selector1=".h3.lh-condensed > a"
# #selector1="div.col-md-6"
# for a in soup1.select(selector1):
#     names4.append(a.get_text().strip())
#
# handles4=[]
# selector2=".f4.text-normal.mb-1"
# for b in soup1.select(selector2):
#     handles4.append(b.get_text().strip())
#
# print(names4)
# print(handles4)
# len(names4), len(handles4)
#
# print((len(soup1.select(selector1))))
#
# selector1=".h3.lh-condensed > a"
# selector2=".f4.text-normal.mb-1"
# def cleaning(list_to_clean):
#     clean_list=[]
#     for i in list_to_clean:
#         clean_list.append(i.get_text().strip())
#     return clean_list
#
# list_names= soup1.select(selector1)
# list_handles=soup1.select(selector2)
#
# names_clean=cleaning(list_names)
# handles_clean=cleaning(list_handles)
# type(names_clean)
# print(names_clean)
# print(handles_clean)
#
#
# dictionary={}
#
# for key in names_clean:
#     for value in handles_clean:
#         if key=='lllyasviel':
#             dictionary[key]= 'NA'
#             break
#         else:
#             dictionary[key] = value
#             handles_clean.remove(value)
#             break
#
# print(dictionary)
# ```
# well this is a solution, although it was manual (identifying the one without a handle and correcting that).

# %% [markdown]
# #### Display the trending Python repositories in GitHub.
#
# The steps to solve this problem is similar to the previous one except that you need to find out the repository names instead of developer names.

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/python?since=daily'

# %%
url2 = 'https://github.com/trending/python?since=daily'
html2=requests.get(url2)
html2
# Out:
# <Response [200]>

# %%
soup2 = BeautifulSoup(html2, 'html.parser')
soup2.prettify()
# Out:
# '<!DOCTYPE html>\n<html data-a11y-animated-images="system" data-color-mode="auto" data-dark-theme="dark" data-light-theme="light" lang="en">\n <head>\n  <meta charset="utf-8"/>\n  <link href="https://github.githubassets.com" rel="dns-prefetch"/>\n  <link href="https://avatars.githubusercontent.com" rel="dns-prefetch"/>\n  <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>\n  <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>\n  <link crossorigin="" href="https://github.githubassets.com" rel="preconnect"/>\n  <link href="https://avatars.githubusercontent.com" rel="preconnect"/>\n  <link crossorigin="anonymous" href="https://github.githubassets.com/assets/light-0946cdc16f15.css" media="all" rel="stylesheet">\n   <link crossorigin="anonymous" href="https://github.githubassets.com/assets/dark-3946c959759a.css" media="all" rel="stylesheet">\n    <link crossorigin="anonymous" data-color-theme="dark_dimmed" data-href="https://github.githubasset
# ...

# %%
container2 = soup2.select("h2.h3.lh-condensed")

# %%
import re
f = container2[0].select_one('a').text.split('/')
f[1].strip()
# Out:
# 'AudioGPT'

# %%
trending_repos=[]
for i in container2:
    e= i.select_one('a').text.split('/')
    f= e[1].strip()
    trending_repos.append(f)
trending_repos
# Out:
# ['AudioGPT',
#  'IF',
#  'WizardLM',
#  'Segment-Everything-Everywhere-All-At-Once',
#  'lamini',
#  'gpt4free',
#  'pandas-ai',
#  'LLaMA-Adapter',
#  'pytube',
#  'discord.py',
#  'authentik',
#  'deforum-stable-diffusion',
#  'spotify-downloader',
#  'FastChat',
#  'skyagi',
#  'Auto-GPT-Crypto-Plugin',
#  'loopgpt',
#  'tango',
#  'system-design-primer',
#  'thinkgpt',
#  'mPLUG-Owl',
#  'biliTickerBuy',
#  'youtube-dl',
#  'trilium-translation',
#  'openai']

# %% [markdown]
# #### Display all the image links from Walt Disney wikipedia page.

# %%
# This is the url you will scrape in this exercise
url3 = 'https://en.wikipedia.org/wiki/Walt_Disney'
html3=requests.get(url3)
html3=html3.content

# %%
soup3 = BeautifulSoup(html3, 'html.parser')
soup3.prettify()
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-language-alert-in-sidebar-enabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-enabled vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled" dir="ltr" lang="en">\n <head>\n  <meta charset="utf-8"/>\n  <title>\n   Walt Disney - Wikipedia\n  </title>\n  <script>\n   document.documentElement.className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-language-alert-in-sidebar-enabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-enabled vector-feature-limited-width-c
# ...

# %%
container3= soup3.select("img")
container3[0]
# Out:
# <img alt="" aria-hidden="true" class="mw-logo-icon" height="50" src="/static/images/icons/wikipedia.png" width="50"/>

# %%
container3[0]["class"]
# Out:
# ['mw-logo-icon']

# %%
container3[17]["class"]
# note that CLASS IS A LIST !!!
# Out:
# ['thumbimage']

# %%
container3[17]["src"]
# Out:
# '//upload.wikimedia.org/wikipedia/commons/thumb/2/2d/Roy_O._Disney_with_Company_at_Press_Conference.jpg/170px-Roy_O._Disney_with_Company_at_Press_Conference.jpg'

# %%
container3[17]
# Out:
# <img class="thumbimage" data-file-height="275" data-file-width="220" decoding="async" height="213" src="//upload.wikimedia.org/wikipedia/commons/thumb/2/2d/Roy_O._Disney_with_Company_at_Press_Conference.jpg/170px-Roy_O._Disney_with_Company_at_Press_Conference.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/2/2d/Roy_O._Disney_with_Company_at_Press_Conference.jpg 1.5x" width="170"/>

# %%
list_images=[]

for i in container3:
    if i.get("class") == ["thumbimage"]:
        link = i["src"]
        list_images.append(link)

list_images

# Autre note : on aurait pu éviter tout ça en se rendant compte que la "classe" dans img, 
# on peut la mettre plus haut (au moment de la construction du container)
# Out:
# ['//upload.wikimedia.org/wikipedia/commons/thumb/3/3a/Walt_Disney_Birthplace_Exterior_Hermosa_Chicago_Illinois.jpg/220px-Walt_Disney_Birthplace_Exterior_Hermosa_Chicago_Illinois.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/c/c4/Walt_Disney_envelope_ca._1921.jpg/220px-Walt_Disney_envelope_ca._1921.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/0/0d/Trolley_Troubles_poster.jpg/170px-Trolley_Troubles_poster.jpg',
#  '//upload.wikimedia.org/wikipedia/en/thumb/4/4e/Steamboat-willie.jpg/170px-Steamboat-willie.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/5/57/Walt_Disney_1935.jpg/170px-Walt_Disney_1935.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Walt_Disney_Snow_white_1937_trailer_screenshot_%2813%29.jpg/220px-Walt_Disney_Snow_white_1937_trailer_screenshot_%2813%29.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/1/15/Disney_drawing_goofy.jpg/170px-Disney_drawing_goofy.jpg',
# ...

# %% [markdown]
# #### Retrieve an arbitary Wikipedia page of "Python" and create a list of links on that page.

# %%
# This is the url you will scrape in this exercise
url ='https://en.wikipedia.org/wiki/Python'

# %%
# your code here

# %% [markdown]
# #### Find the number of titles that have changed in the United States Code since its last release point.

# %%
# This is the url you will scrape in this exercise
url = 'http://uscode.house.gov/download/download.shtml'

# %%
# your code here

# %% [markdown]
# #### Find a Python list with the top ten FBI's Most Wanted names.

# %%
# This is the url you will scrape in this exercise
url = 'https://www.fbi.gov/wanted/topten'

# %%
# your code here

# %% [markdown]
# ####  Display the 20 latest earthquakes info (date, time, latitude, longitude and region name) by the EMSC as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise
url = 'https://www.emsc-csem.org/Earthquake/'

# %%
# your code here

# %% [markdown]
# #### Count the number of tweets by a given Twitter account.
# Ask the user for the handle (@handle) of a twitter account. You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the number of tweets for any provided account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code here

# %% [markdown]
# #### Number of followers of a given twitter account
# Ask the user for the handle (@handle) of a twitter account. You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the followers for any provided account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code here

# %% [markdown]
# #### List all language names and number of related articles in the order they appear in wikipedia.org.

# %%
# This is the url you will scrape in this exercise
url = 'https://www.wikipedia.org/'

# %%
# your code here

# %% [markdown]
# #### A list with the different kind of datasets available in data.gov.uk.

# %%
# This is the url you will scrape in this exercise
url = 'https://data.gov.uk/'

# %%
# your code here

# %% [markdown]
# #### Display the top 10 languages by number of native speakers stored in a pandas dataframe.

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'

# %%
# your code here

# %% [markdown]
# ## Bonus
# #### Scrape a certain number of tweets of a given Twitter account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code here

# %% [markdown]
# #### Display IMDB's top 250 data (movie name, initial release, director name and stars) as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise 
url = 'https://www.imdb.com/chart/top'

# %%
# your code here

# %% [markdown]
# #### Display the movie name, year and a brief summary of the top 10 random movies (IMDB) as a pandas dataframe.

# %%
#This is the url you will scrape in this exercise
url = 'http://www.imdb.com/chart/top'

# %%
# your code here

# %% [markdown]
# #### Find the live weather report (temperature, wind speed, description and weather) of a given city.

# %%
#https://openweathermap.org/current
city = input('Enter the city: ')
url = 'http://api.openweathermap.org/data/2.5/weather?'+'q='+city+'&APPID=b35975e18dc93725acb092f7272cc6b8&units=metric'

# %%
# your code here

# %% [markdown]
# #### Find the book name, price and stock availability as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise. 
# It is a fictional bookstore created to be scraped. 
url = 'http://books.toscrape.com/'

# %%
# your code here
