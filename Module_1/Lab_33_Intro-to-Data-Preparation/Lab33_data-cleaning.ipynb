# %% [markdown]
# # Lab 33 Data cleaning and preparation

# %%
import pandas as pd
data=pd.read_excel('example_data_cleaning.xlsx')
data
# Out:
#     TransactionID  ClientID    BirthYear     Amount   Profession  Department  \
# 0             4.0   34985.0  1923.000000     5670.0      manager        78.0
# 1            16.0   34997.0  1923.000000  2399090.0    developer        78.0
# 2            25.0   35006.0  1923.000000    33050.0           HR        78.0
# 3            12.0   34993.0  1939.142857    23430.0    professor        78.0
# 4            21.0   35002.0  1939.142857    16770.0      manager        78.0
# 5            11.0   34992.0  1943.857143    21210.0   researcher        78.0
# 6            20.0   35001.0  1943.857143    14550.0      student        78.0
# 7             3.0   34984.0  1945.000000     3450.0      student        78.0
# 8            19.0   35000.0  1948.571429    12330.0       barmen        78.0
# 9             9.0   34990.0  1953.285714    16770.0      Manager        78.0
# 10            8.0   34989.0  1958.000000    14550.0           HR        78.0
# ...

# %%
data.drop(columns=['Unnamed: 7','Unnamed: 8'], inplace=True)

# %%
data['Department'].value_counts()
# Out:
# 78.0    30
# Name: Department, dtype: int64

# %%
data.drop(columns=['Department'], inplace=True)
data
# Out:
#     TransactionID  ClientID    BirthYear     Amount   Profession    Risk
# 0             4.0   34985.0  1923.000000     5670.0      manager     Low
# 1            16.0   34997.0  1923.000000  2399090.0    developer    High
# 2            25.0   35006.0  1923.000000    33050.0           HR    High
# 3            12.0   34993.0  1939.142857    23430.0    professor     Low
# 4            21.0   35002.0  1939.142857    16770.0      manager     Low
# 5            11.0   34992.0  1943.857143    21210.0   researcher  Medium
# 6            20.0   35001.0  1943.857143    14550.0      student  Medium
# 7             3.0   34984.0  1945.000000     3450.0      student  Medium
# 8            19.0   35000.0  1948.571429    12330.0       barmen    High
# 9             9.0   34990.0  1953.285714    16770.0      Manager  Medium
# 10            8.0   34989.0  1958.000000    14550.0           HR    High
# 11            6.0   34987.0  1967.000000    10110.0      Manager  Medium
# ...

# %%
data.isnull().sum()
# Out:
# TransactionID    1
# ClientID         1
# BirthYear        3
# Amount           1
# Profession       3
# Risk             1
# dtype: int64

# %%
data.drop([30], axis=0, inplace=True)

# %%
data
# Out:
#     TransactionID  ClientID    BirthYear     Amount   Profession    Risk
# 0             4.0   34985.0  1923.000000     5670.0      manager     Low
# 1            16.0   34997.0  1923.000000  2399090.0    developer    High
# 2            25.0   35006.0  1923.000000    33050.0           HR    High
# 3            12.0   34993.0  1939.142857    23430.0    professor     Low
# 4            21.0   35002.0  1939.142857    16770.0      manager     Low
# 5            11.0   34992.0  1943.857143    21210.0   researcher  Medium
# 6            20.0   35001.0  1943.857143    14550.0      student  Medium
# 7             3.0   34984.0  1945.000000     3450.0      student  Medium
# 8            19.0   35000.0  1948.571429    12330.0       barmen    High
# 9             9.0   34990.0  1953.285714    16770.0      Manager  Medium
# 10            8.0   34989.0  1958.000000    14550.0           HR    High
# 11            6.0   34987.0  1967.000000    10110.0      Manager  Medium
# ...

# %%
data.drop_duplicates()
# Out:
#     TransactionID  ClientID    BirthYear     Amount   Profession    Risk
# 0             4.0   34985.0  1923.000000     5670.0      manager     Low
# 1            16.0   34997.0  1923.000000  2399090.0    developer    High
# 2            25.0   35006.0  1923.000000    33050.0           HR    High
# 3            12.0   34993.0  1939.142857    23430.0    professor     Low
# 4            21.0   35002.0  1939.142857    16770.0      manager     Low
# 5            11.0   34992.0  1943.857143    21210.0   researcher  Medium
# 6            20.0   35001.0  1943.857143    14550.0      student  Medium
# 7             3.0   34984.0  1945.000000     3450.0      student  Medium
# 8            19.0   35000.0  1948.571429    12330.0       barmen    High
# 9             9.0   34990.0  1953.285714    16770.0      Manager  Medium
# 10            8.0   34989.0  1958.000000    14550.0           HR    High
# 11            6.0   34987.0  1967.000000    10110.0      Manager  Medium
# ...

# %%
data.loc[data['ClientID']==34987.0, 'BirthYear'] = 1967.000000

# %%
data
# Out:
#     TransactionID  ClientID    BirthYear     Amount   Profession    Risk
# 0             4.0   34985.0  1923.000000     5670.0      manager     Low
# 1            16.0   34997.0  1923.000000  2399090.0    developer    High
# 2            25.0   35006.0  1923.000000    33050.0           HR    High
# 3            12.0   34993.0  1939.142857    23430.0    professor     Low
# 4            21.0   35002.0  1939.142857    16770.0      manager     Low
# 5            11.0   34992.0  1943.857143    21210.0   researcher  Medium
# 6            20.0   35001.0  1943.857143    14550.0      student  Medium
# 7             3.0   34984.0  1945.000000     3450.0      student  Medium
# 8            19.0   35000.0  1948.571429    12330.0       barmen    High
# 9             9.0   34990.0  1953.285714    16770.0      Manager  Medium
# 10            8.0   34989.0  1958.000000    14550.0           HR    High
# 11            6.0   34987.0  1967.000000    10110.0      Manager  Medium
# ...

# %%
data.loc[data['ClientID']==34988.0, 'BirthYear'] = 1999.000000

# %%
data
# Out:
#     TransactionID  ClientID    BirthYear     Amount   Profession    Risk
# 0             4.0   34985.0  1923.000000     5670.0      manager     Low
# 1            16.0   34997.0  1923.000000  2399090.0    developer    High
# 2            25.0   35006.0  1923.000000    33050.0           HR    High
# 3            12.0   34993.0  1939.142857    23430.0    professor     Low
# 4            21.0   35002.0  1939.142857    16770.0      manager     Low
# 5            11.0   34992.0  1943.857143    21210.0   researcher  Medium
# 6            20.0   35001.0  1943.857143    14550.0      student  Medium
# 7             3.0   34984.0  1945.000000     3450.0      student  Medium
# 8            19.0   35000.0  1948.571429    12330.0       barmen    High
# 9             9.0   34990.0  1953.285714    16770.0      Manager  Medium
# 10            8.0   34989.0  1958.000000    14550.0           HR    High
# 11            6.0   34987.0  1967.000000    10110.0      Manager  Medium
# ...

# %%
data.dtypes
# Out:
# TransactionID    float64
# ClientID         float64
# BirthYear        float64
# Amount           float64
# Profession        object
# Risk              object
# dtype: object

# %%
data['BirthYear'] = data['BirthYear'].astype('int')
data['BirthYear'].dtype
# Out:
# dtype('int64')

# %%
columns=['TransactionID', 'ClientID', 'Amount']
data[columns] = data[columns].astype('int')
data
# Out:
#     TransactionID  ClientID  BirthYear   Amount   Profession    Risk
# 0               4     34985       1923     5670      manager     Low
# 1              16     34997       1923  2399090    developer    High
# 2              25     35006       1923    33050           HR    High
# 3              12     34993       1939    23430    professor     Low
# 4              21     35002       1939    16770      manager     Low
# 5              11     34992       1943    21210   researcher  Medium
# 6              20     35001       1943    14550      student  Medium
# 7               3     34984       1945     3450      student  Medium
# 8              19     35000       1948    12330       barmen    High
# 9               9     34990       1953    16770      Manager  Medium
# 10              8     34989       1958    14550           HR    High
# 11              6     34987       1967    10110      Manager  Medium
# 12             15     34987       1967    30090      Manager     Low
# ...

# %%
data.dtypes
# Out:
# TransactionID     int64
# ClientID          int64
# BirthYear         int64
# Amount            int64
# Profession       object
# Risk             object
# dtype: object

# %%
data['Profession'].value_counts()
# Out:
# Manager        5
# HR             3
# etudient       3
# manager        2
# student        2
# barmen         2
# BDM            2
# developer      1
# professor      1
# researcher     1
# bdm            1
# hr             1
# Hairdresser    1
# Student        1
# Driver         1
# sailer         1
# Name: Profession, dtype: int64

# %%
data['Profession']= data['Profession'].str.replace('Manager', 'manager')
data['Profession']= data['Profession'].str.replace('etudient', 'student')
data['Profession']= data['Profession'].str.replace('Student', 'student')
data['Profession']= data['Profession'].str.replace('HR', 'hr')
data['Profession']= data['Profession'].str.replace('Hairdresser', 'hairdresser')
data['Profession']= data['Profession'].str.replace('Driver', 'driver')
data['Profession']= data['Profession'].str.replace('sailer', 'sailor')

# %%
data
# Out:
#     TransactionID  ClientID  BirthYear   Amount   Profession    Risk
# 0               4     34985       1923     5670      manager     Low
# 1              16     34997       1923  2399090    developer    High
# 2              25     35006       1923    33050           hr    High
# 3              12     34993       1939    23430    professor     Low
# 4              21     35002       1939    16770      manager     Low
# 5              11     34992       1943    21210   researcher  Medium
# 6              20     35001       1943    14550      student  Medium
# 7               3     34984       1945     3450      student  Medium
# 8              19     35000       1948    12330       barmen    High
# 9               9     34990       1953    16770      manager  Medium
# 10              8     34989       1958    14550           hr    High
# 11              6     34987       1967    10110      manager  Medium
# 12             15     34987       1967    30090      manager     Low
# ...

# %%
data.loc[data['ClientID']==35008, 'Profession'] = 'bdm'

# %%
data
# Out:
#     TransactionID  ClientID  BirthYear   Amount   Profession    Risk
# 0               4     34985       1923     5670      manager     Low
# 1              16     34997       1923  2399090    developer    High
# 2              25     35006       1923    33050           hr    High
# 3              12     34993       1939    23430    professor     Low
# 4              21     35002       1939    16770      manager     Low
# 5              11     34992       1943    21210   researcher  Medium
# 6              20     35001       1943    14550      student  Medium
# 7               3     34984       1945     3450      student  Medium
# 8              19     35000       1948    12330       barmen    High
# 9               9     34990       1953    16770      manager  Medium
# 10              8     34989       1958    14550           hr    High
# 11              6     34987       1967    10110      manager  Medium
# 12             15     34987       1967    30090      manager     Low
# ...

# %%
data['Profession']= data['Profession'].str.replace('BDM', 'bdm')

# %%
data['Profession'].value_counts()
# Out:
# manager        7
# student        6
# bdm            5
# hr             4
# barmen         2
# developer      1
# professor      1
# researcher     1
# hairdresser    1
# driver         1
# sailor         1
# Name: Profession, dtype: int64

# %%
list_quart=list(data["Amount"].quantile([0.25, 0.5, 0.75, 0.95]))
list_quart
# Out:
# [12330.0, 18990.0, 29535.0, 53251.999999999985]

# %%
data["Amount"].max()
# Out:
# 2399090

# %%
stats = data.describe().transpose()
stats['IQR'] = stats['75%'] - stats['25%']
stats
# Out:
#                count           mean            std      min       25%  \
# TransactionID   30.0      15.500000       8.803408      1.0      8.25
# ClientID        30.0   34993.833333       8.132876  34982.0  34987.25
# BirthYear       30.0    1969.200000      27.647286   1923.0   1945.75
# Amount          30.0  101009.666667  434261.568869   1230.0  12330.00
#
#                    50%       75%        max       IQR
# TransactionID     15.5     22.75       30.0     14.50
# ClientID       34991.5  34999.75    35008.0     12.50
# BirthYear       1967.0   1988.00     2017.0     42.25
# Amount         18990.0  29535.00  2399090.0  17205.00

# %%
outliers=[]
for col in stats.index:
    iqr = stats.at[col,'IQR']
    cutoff = iqr * 1.5
    lower = stats.at[col,'25%'] - cutoff
    upper = stats.at[col,'75%'] + cutoff
    results = data[(data[col] < lower) | 
                   (data[col] > upper)].copy()
    results['Outlier'] = col
    outliers.append(results)

# %%
outliers
# Out:
# [Empty DataFrame
#  Columns: [TransactionID, ClientID, BirthYear, Amount, Profession, Risk, Outlier]
#  Index: [],
#  Empty DataFrame
#  Columns: [TransactionID, ClientID, BirthYear, Amount, Profession, Risk, Outlier]
#  Index: [],
#  Empty DataFrame
#  Columns: [TransactionID, ClientID, BirthYear, Amount, Profession, Risk, Outlier]
#  Index: [],
#     TransactionID  ClientID  BirthYear   Amount Profession  Risk Outlier
#  1             16     34997       1923  2399090  developer  High  Amount]

# %%
data.drop([1], axis=0, inplace=True)

# %%
data
# Out:
#     TransactionID  ClientID  BirthYear  Amount   Profession    Risk
# 0               4     34985       1923    5670      manager     Low
# 2              25     35006       1923   33050           hr    High
# 3              12     34993       1939   23430    professor     Low
# 4              21     35002       1939   16770      manager     Low
# 5              11     34992       1943   21210   researcher  Medium
# 6              20     35001       1943   14550      student  Medium
# 7               3     34984       1945    3450      student  Medium
# 8              19     35000       1948   12330       barmen    High
# 9               9     34990       1953   16770      manager  Medium
# 10              8     34989       1958   14550           hr    High
# 11              6     34987       1967   10110      manager  Medium
# 12             15     34987       1967   30090      manager     Low
# 13             24     34989       1967   27870           hr  Medium
# ...

# %%
data['Risk'].value_counts()
# Out:
# Medium    11
# Low       10
# High       8
# Name: Risk, dtype: int64

# %%
data.to_csv("example_data_clean.csv", sep=";", index=False)
